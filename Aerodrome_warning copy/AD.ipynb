# %%
import pandas as pd
import re
pd.set_option('display.max_rows', None)

with open("AERODROM WARNING COMPOSITE 0F SEPTEMBER 2023.txt", "r", encoding="utf-8") as f:
    lines = [line.strip() for line in f if line.strip()]

data = []
i = 0
while i < len(lines):
    
    if "WARNING" in lines[i] :
        i += 2
        if i >= len(lines): break
        
        
        main_line = lines[i]
        main_parts = main_line.split()
        station = main_parts[0]
        issue_time = f"{main_parts[1]}Z"
        validity_from, validity_to = "", ""
        valid_match = re.search(r"VALID\s*(\d{6,8})/(\d{6,8})", main_line)
        if valid_match:
            validity_from = valid_match.group(1)
            validity_to = valid_match.group(2)
        
        
        i += 1
        if i >= len(lines): break
        wx_line = lines[i]
        wind_dir, wind_speed, gust, sig_wx, fcst_obs = "", "", "", "", ""
        
        
        wind_speed_match = re.search(r"SFC WSPD (\d+KT)", wx_line)
        wind_speed = wind_speed_match.group(1) if wind_speed_match else ""
        
        gust_match = re.search(r"MAX(\d+)", wx_line)
        gust = f"{gust_match.group(1)}KT" if gust_match else ""
        
        
        wind_dir_dict = {
            "N": 0,
            "NNE": 20,
            "NE": 50,
            "ENE": 70,
            "E": 90,
            "ESE": 110,
            "SE": 140,
            "SSE": 160,
            "S": 180,
            "SSW": 200,
            "SW": 230,
            "WSW": 250,
            "W": 270,
            "WNW": 290,
            "NW": 320,
            "NNW": 340
        }
        wind_dir_match = re.search(r"FROM\s+([A-Z]+)", wx_line)
        if wind_dir_match:
            wind_dir_str = wind_dir_match.group(1).strip()
            wind_dir = wind_dir_str
            wind_dir_num = wind_dir_dict.get(wind_dir_str, "")
        else:
            wind_dir = ""
            wind_dir_num = ""
        
        sig_wx_match = re.search(r"(TSRA|TS|FBL TSRA|MOD TSRA|HVY TSRA|MOD TS|FBL TS|HVY TS)", wx_line)
        sig_wx = sig_wx_match.group(1) if sig_wx_match else ""
        if "HVY TSRA" in wx_line:
            sig_wx = "+TSRA"
        elif "FBL TSRA" in wx_line:
            sig_wx = "-TSRA"
        elif "MOD TSRA" in wx_line or "TSRA" in wx_line:
            sig_wx = "TSRA"
        elif "HVY TS" in wx_line:
            sig_wx = "+TS"
        elif "FBL TS" in wx_line:
            sig_wx = "-TS"
        elif "MOD TS" in wx_line or "TS" in wx_line:
            sig_wx = "TS"
        else:
            sig_wx = ""
        
        
        if "FCST" in wx_line:
            fcst_obs = "FCST"
        elif "OBS" in wx_line or "OBSD" in wx_line:
            fcst_obs = "OBS"
        
        data.append({
            "Station": station,
            "Issue date/time": issue_time,
            "Validity from": validity_from,
            "Validity To": validity_to,
            "Wind dir (deg)": wind_dir_num,
            "Wind Speed": wind_speed,
            "Gust": gust,
            "Significant Wx": sig_wx,
            "FCST/OBS": fcst_obs
        })
    i += 1


df = pd.DataFrame(data)

df["Wind dir (deg)"] = pd.to_numeric(df["Wind dir (deg)"], errors="coerce").astype("Int64")

# %%
df
# Out:
#    Station Issue date/time Validity from Validity To  Wind dir (deg)  \
# 0     VABB         040730Z        040800      041200             250
# 1     VABB         060715Z        060730      061130             270
# 2     VABB         062300Z        062300      070300             250
# 3     VABB         100330Z        100400      100800             270
# 4     VABB         100730Z        100800      101200             270
# 5     VABB         110630Z        110700      111100            <NA>
# 6     VABB         111030Z        111100      111500             250
# 7     VABB         111300Z        111330      111730             250
# 8     VABB         120800Z        120830      121230             250
# 9     VABB         161030Z        161100      161500             250
# 10    VAJJ         161030Z        161100      161500             250
# 11    VABB         162325Z        162330      170330             250
# 12    VABB         170315Z        170315      170715             230
# 13    VAJJ         170315Z        170315      170715             230
# 14    VABB         170715Z        170715      171115             230
# 15    VAJJ         170715Z        170715      171115             230
# 16    VABB         171045Z        171115      171515             250
# 17    VAJJ         171045Z        171115      171515             250
# 18    VABB         172300Z        172330      180330             230
# 19    VAJJ         172300Z        172330      180330             230
# 20    VABB         180415Z        180415      180815             230
# 21    VAJJ         180415Z        180415      180815             230
# 22    VABB         180745Z        180815      181215             230
# 23    VAJJ         180745Z        180815      181215             230
# 24    VABB         181145Z        181215      181615             230
# 25    VAJJ         181145Z        181215      181615             230
# 26    VABB         181730Z        181745      182145             230
# 27    VAJJ         181730Z        181745      182145             230
# 28    VABB         190545Z        190600      191000             230
# 29    VAJJ         190545Z        190600      191000             230
# 30    VABB         200530Z        200600      201000             200
# 31    VAJJ         200530Z        200600      201000             200
# 32    VABB         200830Z        200900      201300             200
# 33    VAJJ         200830Z        200900      201300             200
# 34    VABB         201230Z        201300      201700             180
# 35    VABB         201630Z        201700      202100             160
# 36    VABB         202130Z        202200      210200             160
# 37    VABB         210130Z        210200      210600             180
# 38    VAJJ         210130Z        210200      210600             180
# 39    VABB         210930Z        211000      211400             200
# 40    VAJJ         210930Z        211000      211400             200
# 41    VABB         211330Z        211400      211800             200
# 42    VAJJ         211330Z        211400      211800             200
# 43    VABB         211730Z        211800      212200             200
# 44    VABB         212130Z        212200      220200             200
# 45    VABB         220630Z        220700      221100            <NA>
# 46    VABB         221530Z        221600      222000             180
# 47    VABB         221930Z        222000      222400             180
# 48    VABB         222330Z        230000      230400             180
# 49    VAJJ         222330Z        230000      230400             180
# 50    VABB         230630Z        230700      231100             250
# 51    VAJJ         230630Z        230700      231100             250
# 52    VABB         231130Z        231200      231600            <NA>
# 53    VAJJ         231130Z        231200      231600            <NA>
# 54    VABB         231640Z        231700      232100            <NA>
# 55    VAJJ         231640Z        231700      232100            <NA>
# 56    VABB         240615Z        240640      241040             250
# 57    VAJJ         240615Z        240640      241040             250
# 58    VABB         241230Z        241300      241700            <NA>
# 59    VABB         250430Z        250500      250900             230
# 60    VAJJ         250430Z        250500      250900             230
# 61    VABB         251300Z        251330      251730             290
# 62    VABB        261230ZZ        261300      261700             290
# 63    VABB        261630ZZ        261700      262100            <NA>
# 64    VABB         270700Z        270730      271130            <NA>
# 65    VABB         271430Z        271500      271900              70
# 66    VABB         280700Z        280730      281130              70
# 67    VABB         280945Z        280945      281345             230
# 68    VAJJ         280945Z        280945      281345             230
# 69    VABB         281615Z        281615      282015              50
# 70    VABB         290700Z        290730      291130             290
# 71    VABB         291100Z        291130      291530            <NA>
# 72    VAJJ         291100Z        291130      291530            <NA>
# 73    VABB         291500Z        291530      291930            <NA>
# 74    VABB         291500Z        291530      291930            <NA>
# 75    VABB         301330Z        301400      301800              70
# 76    VABB         301415Z        301430      301830            <NA>
# 77    VABB         301800Z        301830      302230              20
# 78    VABB         302200Z        302230     0102300              20
# 79    VAJJ         302200Z        302230     0102300              20
#
#    Wind Speed  Gust Significant Wx FCST/OBS
# 0        17KT  27KT                    FCST
# 1        17KT  27KT                    FCST
# 2        17KT  27KT                     OBS
# 3        17KT  27KT                    FCST
# 4        17KT  27KT                    FCST
# 5        17KT  27KT                    FCST
# 6        17KT  27KT                    FCST
# 7        17KT  27KT           TSRA     FCST
# 8        17KT  27KT                    FCST
# 9        17KT  27KT                    FCST
# 10       17KT  27KT                    FCST
# 11       17KT  27KT                     OBS
# 12       17KT  27KT                     OBS
# 13       17KT  27KT                     OBS
# 14       17KT  30KT                     OBS
# 15       17KT  30KT                     OBS
# 16       17KT  27KT
# 17       17KT  27KT
# 18       17KT  27KT                    FCST
# 19       17KT  27KT                    FCST
# 20       17KT  27KT                     OBS
# 21       17KT  27KT                     OBS
# 22       17KT  27KT                    FCST
# 23       17KT  27KT                    FCST
# 24       17KT  27KT                    FCST
# 25       17KT  27KT                    FCST
# 26       17KT  27KT                    FCST
# 27       17KT  27KT                    FCST
# 28       17KT  27KT                    FCST
# 29       17KT  27KT                    FCST
# 30       17KT  27KT                    FCST
# 31       17KT  27KT                    FCST
# 32       17KT  27KT           TSRA     FCST
# 33       17KT  27KT           TSRA     FCST
# 34       17KT  27KT           TSRA     FCST
# 35       17KT  27KT           TSRA     FCST
# 36       17KT  27KT           TSRA     FCST
# 37       17KT  27KT           TSRA     FCST
# 38       17KT  27KT           TSRA     FCST
# 39       17KT  27KT          -TSRA     FCST
# 40       17KT  27KT          -TSRA     FCST
# 41       17KT  27KT          -TSRA     FCST
# 42       17KT  27KT          -TSRA     FCST
# 43       17KT  27KT          -TSRA     FCST
# 44       17KT  27KT           TSRA     FCST
# 45                            TSRA
# 46       17KT  27KT           TSRA     FCST
# 47       17KT  27KT           TSRA     FCST
# 48       17KT  27KT           TSRA     FCST
# 49       17KT  27KT           TSRA     FCST
# 50       17KT  27KT           TSRA     FCST
# 51       17KT  27KT           TSRA     FCST
# 52                            TSRA     FCST
# 53                            TSRA     FCST
# 54                            TSRA     FCST
# 55                            TSRA     FCST
# 56       17KT  27KT          -TSRA     FCST
# 57       17KT  27KT          -TSRA     FCST
# 58                            TSRA     FCST
# 59       17KT  27KT                    FCST
# 60       17KT  27KT                    FCST
# 61       17KT  27KT           TSRA     FCST
# 62       17KT  27KT             TS     FCST
# 63                            TSRA     FCST
# 64                            TSRA
# 65       17KT  27KT          +TSRA     FCST
# 66       17KT  27KT            -TS     FCST
# 67       17KT  27KT           TSRA      OBS
# 68       17KT  27KT           TSRA      OBS
# 69       17KT  27KT          -TSRA      OBS
# 70       17KT  27KT            -TS     FCST
# 71                            TSRA     FCST
# 72                            TSRA     FCST
# 73                            TSRA     FCST
# 74                            TSRA     FCST
# 75       20KT  30KT                     OBS
# 76                            TSRA      OBS
# 77       20KT  30KT           TSRA     FCST
# 78       17KT  27KT           TSRA     FCST
# 79       17KT  27KT           TSRA     FCST

# %%
df.describe()
# Out:
#        Station Issue date/time Validity from Validity To Wind dir  \
# count       80              80            80          80       80
# unique       2              55            55          55       12
# top       VABB          180745        180815      181215       SW
# freq        56               2             2           2       20
#
#         Wind dir (deg) Wind Speed  Gust Significant Wx FCST/OBS
# count               80         80    80             80       80
# unique              11          3     3              6        3
# top                230       17KT  27KT                    FCST
# freq                20         65    63             34       63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Station          80 non-null     object
#  1   Issue date/time  80 non-null     object
#  2   Validity from    80 non-null     object
#  3   Validity To      80 non-null     object
#  4   Wind dir (deg)   66 non-null     Int64
#  5   Wind Speed       80 non-null     object
#  6   Gust             80 non-null     object
#  7   Significant Wx   80 non-null     object
#  8   FCST/OBS         80 non-null     object
# dtypes: Int64(1), object(8)
# memory usage: 5.8+ KB

# %%
import pandas as pd
import re

# Read warnings
ad_warn_df = pd.read_csv('AD_warn_DF.csv')

# Read METAR lines
with open('metar.txt', 'r') as f:
    metar_lines = [line.strip() for line in f if line.strip()]

def get_metar_time_group(metar):
    # Try to extract the Z group (e.g., 231105Z)
    match = re.search(r'\b(\d{6}Z)\b', metar)
    if match:
        return match.group(1)[:-1]  # Remove 'Z'
    # If not found, try to extract the full timestamp and round minutes down to zero
    match_full = re.match(r'(\d{8})(\d{4})', metar)
    if match_full:
        date_part = match_full.group(1)  # YYYYMMDD
        time_part = match_full.group(2)  # HHMM
        hour = time_part[:2]
        # Round minutes down to zero
        rounded_time = f"{date_part}{hour}00"
        # Return last 6 digits (no 'Z')
        return rounded_time[-6:]
    return None

def extract_metar_features():
    for idx, row in ad_warn_df.iterrows():
        fcst_obs = str(row.get('FCST/OBS', '')).strip().upper()
        if fcst_obs != 'FCST':
            print(f'\nRow {idx+1}: FCST/OBS is {fcst_obs}, skipping extraction.')
            continue
        validity_from = str(row.get('Validity from', '')).replace('Z', '')
        validity_to = str(row.get('Validity To', '')).replace('Z', '')
        print(f'\nRow {idx+1}: Validity {validity_from} to {validity_to}')
        extracting = False
        for metar in metar_lines:
            metar_time = get_metar_time_group(metar)
            if not metar_time:
                continue
            if metar_time == validity_from:
                extracting = True
            if extracting:
                # Extract wind group (e.g., 28010G17KT or 28010KT)
                wind_match = re.search(r' (\d{3})(\d{2})(G(\d{2,3}))?KT', metar)
                wind_dir = int(wind_match.group(1)) if wind_match else None
                wind_gust = int(wind_match.group(4)) if wind_match and wind_match.group(4) else None
                # Extract cloud groups (e.g., SCT020 SCT025)
                clouds = re.findall(r'(FEW\d{3}|SCT\d{3}|BKN\d{3}|OVC\d{3})', metar)
                print(f'  METAR: {metar}')
                print(f'    Wind Dir: {wind_dir}, Gust: {wind_gust}, Clouds: {clouds}')
            if metar_time == validity_to and extracting:
                break

if __name__ == '__main__':
    extract_metar_features()
# Out:
# Row 1: Validity 040800 to 041200
#   METAR: 202309040800 METAR VABB 040800Z 28010KT 3000 HZ SCT020 SCT025 31/25 Q1006 NOSIG=
#     Wind Dir: 280, Gust: None, Clouds: ['SCT020', 'SCT025']
#   METAR: 202

#     Wind Dir: 250, Gust: None, Clouds: ['SCT018', 'SCT025']
#   METAR: 202309100705 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309100730 METAR VABB 100730Z 26007G17KT 3500 HZ SCT018 SCT025 31/26 Q1006 NOSIG=
#     Wind Dir: 260, Gust: 17, Clouds: ['SCT018', 'SCT025']
#   METAR: 202309100800 METAR VABB 100800Z 25009G19KT 3500 HZ SCT018 SCT025 BKN100 31/26 Q1006 NOSIG=
#     Wind Dir: 250, Gust: 19, Clouds: ['SCT018', 'SCT025', 'BKN100']
#
# Row 5: Validity 100800 to 101200
#   METAR: 202309100800 METAR VABB 100800Z 25009G19KT 3500 HZ SCT018 SCT025 BKN100 31/26 Q1006 NOSIG=
#     Wind Dir: 250, Gust: 19, Clouds: ['SCT018', 'SCT025', 'BKN100']
#   METAR: 202309100805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309100830 METAR VABB 100830Z 26011KT 3500 HZ SCT018 SCT025 BKN100 31/27 Q1006 NOSIG=
#     Wind Dir: 260, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN100']
#   METAR: 202309100905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309100930 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309101005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309101030 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309101100 METAR VABB 101100Z 26011KT 3500 HZ SCT018 FEW025TCU BKN100 30/26 Q1005 NOSIG=
#     Wind Dir: 260, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN100']
#   METAR: 202309101105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309101130 METAR VABB 101130Z 29010KT 3000 SHRA FEW012 SCT018 FEW025TCU BKN090 30/27 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 290, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'BKN090']
#   METAR: 202309101200 METAR VABB 101200Z 24011KT 3000 SHRA FEW012 SCT018 FEW025TCU BKN090 30/27 Q1005 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'BKN090']
#
# Row 6: Validity 110700 to 111100
#   METAR: 202309110700 METAR VABB 110700Z 24007G17KT 5000 HZ SCT020 SCT025 31/27 Q1007 NOSIG=
#     Wind Dir: 240, Gust: 17, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309110705 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309110730 METAR VABB 110730Z 26010G20KT 5000 HZ SCT020 SCT025 31/27 Q1007 NOSIG=
#     Wind Dir: 260, Gust: 20, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309110800 METAR VABB 110800Z 28007G17KT 5000 HZ SCT020 SCT025 31/26 Q1006 NOSIG=
#     Wind Dir: 280, Gust: 17, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309110805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309110830 METAR VABB 110830Z 28007G17KT 5000 HZ SCT020 SCT025 31/27 Q1006 NOSIG=
#     Wind Dir: 280, Gust: 17, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309110900 METAR VABB 110900Z 27009G19KT 5000 HZ SCT020 SCT025 31/26 Q1006 NOSIG=
#     Wind Dir: 270, Gust: 19, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309110905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309110930 METAR VABB 110930Z 30007G17KT 5000 HZ SCT020 SCT025 31/29 Q1006 NOSIG=
#     Wind Dir: 300, Gust: 17, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309111000 METAR VABB 111000Z 26007G17KT 5000 HZ SCT020 SCT025 30/26 Q1005 TEMPO 3000 -SHRA=
#     Wind Dir: 260, Gust: 17, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309111005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309111030 METAR VABB 111030Z 27007G17KT 5000 HZ SCT020 SCT025 31/26 Q1005 NOSIG=
#     Wind Dir: 270, Gust: 17, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309111100 METAR VABB 111100Z 29012KT 5000 HZ SCT020 SCT025 30/26 Q1005 NOSIG=
#     Wind Dir: 290, Gust: None, Clouds: ['SCT020', 'SCT025']
#
# Row 7: Validity 111100 to 111500
#   METAR: 202309111100 METAR VABB 111100Z 29012KT 5000 HZ SCT020 SCT025 30/26 Q1005 NOSIG=
#     Wind Dir: 290, Gust: None, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309111105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309111130 METAR VABB 111130Z 28011KT 5000 HZ SCT020 SCT025 31/25 Q1005 NOSIG=
#     Wind Dir: 280, Gust: None, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309111200 METAR VABB 111200Z 30007G17KT 5000 HZ SCT020 SCT025 31/26 Q1006 NOSIG=
#     Wind Dir: 300, Gust: 17, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309111205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309111230 METAR VABB 111230Z 31010KT 4000 HZ SCT020 SCT025 30/28 Q1006 NOSIG=
#     Wind Dir: 310, Gust: None, Clouds: ['SCT020', 'SCT025']
#   METAR: 202309
27 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC080']
#   METAR: 202309161200 METAR VABB 161200Z 24010KT 3000 HZ FEW012 SCT018 FEW025TCU OVC090 29/26 Q1005 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC090']
#   METAR: 202309161205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309161230 METAR VABB 161230Z 24008KT 1500 RA FEW012 SCT018 FEW025TCU OVC090 29/26 Q1005 TEMPO 0800 +RA=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC090']
#   METAR: 202309161300 METAR VABB 161300Z 25009KT 2500 -DZ FEW012 SCT018 FEW025TCU OVC090 25/25 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 250, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC090']
#   METAR: 202309161305 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309161330 METAR VABB 161330Z 24008KT 2500 HZ FEW012 SCT018 FEW025TCU OVC090 28/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC090']
#   METAR: 202309161400 METAR VABB 161400Z 23006KT 2500 HZ FEW012 SCT018 FEW025TCU OVC090 28/26 Q1005 NOSIG=
#     Wind Dir: 230, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC090']
#   METAR: 202309161405 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309161430 METAR VABB 161430Z 24009KT 2500 HZ FEW012 SCT018 FEW025TCU OVC090 28/26 Q1005 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC090']
#   METAR: 202309161500 METAR VABB 161500Z 24009KT 2500 HZ FEW012 SCT018 FEW025TCU OVC090 29/26 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC090']
#
# Row 11: FCST/OBS is OBS, skipping extraction.
#
# Row 12: FCST/OBS is OBS, skipping extraction.
#
# Row 13: FCST/OBS is OBS, skipping extraction.
#
# Row 14: FCST/OBS is NAN, skipping extraction.
#
# Row 15: Validity 172330 to 180330
#   METAR: 202309172330 METAR VABB 172330Z 23007KT 2200 -DZ SCT018 SCT025 BKN090 27/25 Q1004 TEMPO 1500 SHRA=
#     Wind Dir: 230, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN090']
#   METAR: 202309180000 METAR VABB 180000Z 22003KT 2200 BR SCT018 SCT025 BKN090 27/25 Q1004 NOSIG=
#     Wind Dir: 220, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN090']
#   METAR: 202309180005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309180030 METAR VABB 180030Z 23009KT 2200 BR SCT018 SCT025 BKN090 28/26 Q1004 NOSIG=
#     Wind Dir: 230, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN090']
#   METAR: 202309180100 METAR VABB 180100Z 22008KT 2500 HZ SCT018 FEW025 SCT100 28/26 Q1004 NOSIG=
#     Wind Dir: 220, Gust: None, Clouds: ['SCT018', 'FEW025', 'SCT100']
#   METAR: 202309180105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309180130 METAR VABB 180130Z 24005KT 2500 HZ SCT018 SCT025 BKN100 28/26 Q1004 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN100']
#   METAR: 202309180200 METAR VABB 180200Z 21009KT 2500 -DZ FEW012 SCT018 SCT025 BKN090 26/26 Q1004 NOSIG=
#     Wind Dir: 210, Gust: None, Clouds: ['FEW012', 'SCT018', 'SCT025', 'BKN090']
#   METAR: 202309180205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309180230 METAR VABB 180230Z 19005KT 3000 BR SCT020 SCT025 BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 190, Gust: None, Clouds: ['SCT020', 'SCT025', 'BKN090']
#   METAR: 202309180300 METAR VABB 180300Z 21007KT 3000 BR SCT020 SCT025 BKN090 29/27 Q1005 NOSIG=
#     Wind Dir: 210, Gust: None, Clouds: ['SCT020', 'SCT025', 'BKN090']
#   METAR: 202309180305 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309180330 METAR VABB 180330Z 22010KT 3000 BR SCT020 SCT025 BKN090 29/27 Q1006 NOSIG=
#     Wind Dir: 220, Gust: None, Clouds: ['SCT020', 'SCT025', 'BKN090']
#
# Row 16: FCST/OBS is OBS, skipping extraction.
#
# Row 17: Validity 180800 to 181230
#   METAR: 202309180800 METAR VABB 180800Z 21011G21KT 3000 VCSH SCT020 SCT025 BKN090 30/27 Q1004 TEMPO 1500 SHRA=
#     Wind Dir: 210, Gust: 21, Clouds: ['SCT020', 'SCT025', 'BKN090']
#   METAR: 202309180805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309180830 METAR VABB 180830Z 24007G17KT 1700 RA FEW012 SCT020 BKN090 27/26 Q1004 TEMPO 0800 +SHRA=
#     Wind Dir: 240, Gust: 17, Clouds: ['FEW012', 'SCT020', 'BKN090']
#   METAR: 202309180900 METAR VABB 180900Z 24012G22KT 2500 HZ FEW012 SCT020 BKN090 28/28 Q1004 TEMPO 1500 SHRA=
#     Wind Dir: 240, Gust: 22, Clouds: ['FEW012', 'SCT020', 'BKN090']
#   METAR: 202309180905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309180930 METAR VABB 180930Z 26007G17KT 2500 HZ FEW012 SCT020 BKN090 30/28 Q1004 TEMPO 1500 SHRA=
#     Wind Dir: 260, Gust: 17, Clouds: ['FEW012', 'SCT020', 'BKN090']
#   METAR: 202309181000 METAR VABB 181000Z 23008G18KT 2500 HZ FEW018 SCT025 BKN100 31/27 Q1003 BECMG 3000 HZ=
#     Wind Dir: 230, Gust: 18, Clouds: ['FEW018', 'SCT025', 'BKN100']
#   METAR: 202309181005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181030 METAR VABB 181030Z 21010KT 3000 HZ FEW018 SCT025 BKN100 30/27 Q1003 NOSIG=
#     Wind Dir: 210, Gust: None, Clouds: ['FEW018', 'SCT025', 'BKN100']
#   METAR: 202309181100 METAR VABB 181100Z 22014KT 2500 VCSH FEW010 SCT018 BKN090 30/26 Q1003 TEMPO 1500 SHRA=
#     Wind Dir: 220, Gust: None, Clouds: ['FEW010', 'SCT018', 'BKN090']
#   METAR: 202309181105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181130 METAR VABB 181130Z 20005KT 2200 VCSH FEW010 SCT018 BKN090 26/25 Q1004 TEMPO 1500 SHRA=
#     Wind Dir: 200, Gust: None, Clouds: ['FEW010', 'SCT018', 'BKN090']
#   METAR: 202309181200 METAR VABB 181200Z 24009KT 2500 -DZ SCT018 SCT025 BKN090 27/27 Q1004 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN090']
#   METAR: 202309181205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181230 METAR VABB 181230Z 23011KT 2500 HZ SCT018 SCT025 BKN090 28/27 Q1004 NOSIG=
#     Wind Dir: 230, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN090']
#
# Row 18: Validity 181200 to 181630
#   METAR: 202309181200 METAR VABB 181200Z 24009KT 2500 -DZ SCT018 SCT025 BKN090 27/27 Q1004 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN090']
#   METAR: 202309181205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181230 METAR VABB 181230Z 23011KT 2500 HZ SCT018 SCT025 BKN090 28/27 Q1004 NOSIG=
#     Wind Dir: 230, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN090']
#   METAR: 202309181300 METAR VABB 181300Z 22007KT 2500 VCSH SCT018 SCT025 BKN090 28/27 Q1004 NOSIG=
#     Wind Dir: 220, Gust: None, Clouds: ['SCT018', 'SCT025', 'BKN090']
#   METAR: 202309181305 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181330 METAR VABB 181330Z 21010KT 2500 -RA FEW010 SCT018 BKN090 28/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 210, Gust: None, Clouds: ['FEW010', 'SCT018', 'BKN090']
#   METAR: 202309181400 METAR VABB 181400Z 25014G24KT 2100 RA FEW010 SCT018 FEW025TCU OVC090 26/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 250, Gust: 24, Clouds: ['FEW010', 'SCT018', 'FEW025', 'OVC090']
#   METAR: 202309181405 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181430 METAR VABB 181430Z 25010KT 2500 -DZ SCT018 FEW025TCU OVC090 26/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 250, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC090']
#   METAR: 202309181500 METAR VABB 181500Z 24007KT 2500 DZ SCT018 FEW025TCU OVC090 27/26 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC090']
#   METAR: 202309181505 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181530 METAR VABB 181530Z 23005KT 2500 -DZ SCT018 FEW025TCU OVC090 27/26 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 230, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC090']
#   METAR: 202309181600 METAR VABB 181600Z 15003KT 2500 DZ SCT018 FEW025TCU OVC090 27/26 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 150, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC090']
#   METAR: 202309181605 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181630 METAR VABB 181630Z 18004KT 2500 BR SCT018 FEW025TCU OVC080 27/26 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 180, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC080']
#
# Row 19: Validity 181730 to 182200
#   METAR: 202309181730 METAR VABB 181730Z 21008KT 1800 RA FEW012 SCT018 FEW025TCU OVC080 28/26 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 210, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC080']
#   METAR: 202309181800 METAR VABB 181800Z 24007KT 2100 VCSH FEW012 SCT018 FEW025TCU OVC080 26/26 Q1007 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW025', 'OVC080']
#   METAR: 202309181805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181830 METAR VABB 181830Z 21005KT 2500 BR SCT018 FEW025TCU OVC080 27/26 Q1007 NOSIG=
#     Wind Dir: 210, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC080']
#   METAR: 202309181900 METAR VABB 181900Z 14003KT 2500 BR SCT018 FEW025TCU OVC080 27/27 Q1006 NOSIG=
#     Wind Dir: 140, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC080']
#   METAR: 202309181905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309181930 METAR VABB 181930Z 16006KT 2500 BR SCT018 FEW025TCU OVC080 27/27 Q1006 NOSIG=
#     Wind Dir: 160, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC080']
#   METAR: 202309182000 METAR VABB 182000Z 18007KT 2500 BR SCT018 FEW025TCU OVC090 27/26 Q1006 NOSIG=
#     Wind Dir: 180, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC090']
#   METAR: 202309182005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309182030 METAR VABB 182030Z 16006KT 2500 BR SCT018 FEW025TCU OVC090 27/26 Q1006 NOSIG=
#     Wind Dir: 160, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC090']
#   METAR: 202309182100 METAR VABB 182100Z 21007KT 2500 -DZ SCT018 FEW025TCU OVC090 27/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 210, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC090']
#   METAR: 202309182105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309182130 METAR VABB 182130Z 19004KT 2500 BR SCT018 FEW025TCU OVC090 27/27 Q1005 NOSIG=
#     Wind Dir: 190, Gust: None, Clouds: ['SCT018', 'FEW025', 'OVC090']
#   METAR: 202309182200 METAR VABB 182200Z 16004KT 2500 BR SCT018 FEW025TCU BKN090 27/27 Q1005 NOSIG=
#     Wind Dir: 160, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#
# Row 20: Validity 190600 to 191000
#   METAR: 202309190600 METAR VABB 190600Z 22010G20KT 2500 HZ SCT018 FEW025TCU BKN090 31/27 Q1007 BECMG 3000 HZ=
#     Wind Dir: 220, Gust: 20, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309190605 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309190630 METAR VABB 190630Z 22013KT 3000 HZ SCT018 FEW025TCU BKN090 31/27 Q1007 NOSIG=
#     Wind Dir: 220, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309190700 METAR VABB 190700Z 21012G22KT 3000 HZ SCT018 FEW025TCU BKN090 31/27 Q1007 NOSIG=
#     Wind Dir: 210, Gust: 22, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309190705 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309190730 METAR VABB 190730Z 23009G19KT 3000 HZ SCT018 FEW025TCU BKN090 31/27 Q1007 NOSIG=
#     Wind Dir: 230, Gust: 19, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309190800 METAR VABB 190800Z 23008G18KT 3000 HZ SCT018 FEW025TCU 31/27 Q1006 NOSIG=
#     Wind Dir: 230, Gust: 18, Clouds: ['SCT018', 'FEW025']
#   METAR: 202309190805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309190830 METAR VABB 190830Z 21012G22KT 3000 HZ SCT018 FEW025TCU 31/26 Q1006 NOSIG=
#     Wind Dir: 210, Gust: 22, Clouds: ['SCT018', 'FEW025']
#   METAR: 202309190900 METAR VABB 190900Z 22009G19KT 3000 HZ SCT018 FEW025TCU 31/27 Q1006 NOSIG=
#     Wind Dir: 220, Gust: 19, Clouds: ['SCT018', 'FEW025']
#   METAR: 202309190905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309190930 METAR VABB 190930Z 23012KT 3000 HZ SCT018 FEW025TCU 31/28 Q1006 NOSIG=
#     Wind Dir: 230, Gust: None, Clouds: ['SCT018', 'FEW025']
#   METAR: 202309191000 METAR VABB 191000Z 22008G18KT 3000 HZ SCT018 FEW025TCU 31/26 Q1006 NOSIG=
#     Wind Dir: 220, Gust: 18, Clouds: ['SCT018', 'FEW025']
#
# Row 21: Validity 200600 to 201000
#   METAR: 202309200600 METAR VABB 200600Z 18007G17KT 3000 HZ SCT018 SCT025 BKN090 31/28 Q1008 NOSIG=
#     Wind Dir: 180, Gust: 17, Clouds: ['SCT018', 'SCT025', 'BKN090']
#   METAR: 202309200605 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202

#     Wind Dir: 250, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN090']
#   METAR: 202309211100 METAR VABB 211100Z 26012KT 3500 HZ SCT018 SCT025 FEW030CB BKN090 30/26 Q1006 NOSIG=
#     Wind Dir: 260, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN090']
#   METAR: 202309211105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211130 METAR VABB 211130Z 24011KT 3500 HZ SCT018 SCT025 FEW030CB BKN100 29/27 Q1006 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN100']
#   METAR: 202309211200 METAR VABB 211200Z 24009KT 3500 HZ SCT018 SCT025 FEW030CB BKN100 29/27 Q1006 NOSIG=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN100']
#   METAR: 202309211205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211230 METAR VABB 211230Z 27007KT 3500 HZ SCT018 SCT025 FEW030CB BKN100 29/28 Q1006 NOSIG=
#     Wind Dir: 270, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN100']
#   METAR: 202309211300 METAR VABB 211300Z 24007KT 3500 HZ SCT018 SCT025 FEW030CB BKN100 29/26 Q1007 BECMG 3000 HZ=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN100']
#   METAR: 202309211305 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211330 METAR VABB 211330Z 24005KT 3000 TS SCT018 SCT025 FEW030CB BKN090 29/26 Q1008 TEMPO 1500 TSRA=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN090']
#   METAR: 202309211400 METAR VABB 211400Z 28004KT 3000 TS SCT018 SCT025 FEW030CB BKN090 29/26 Q1008 TEMPO 1500 TSRA=
#     Wind Dir: 280, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN090']
#
# Row 28: Validity 211400 to 211800
#   METAR: 202309211400 METAR VABB 211400Z 28004KT 3000 TS SCT018 SCT025 FEW030CB BKN090 29/26 Q1008 TEMPO 1500 TSRA=
#     Wind Dir: 280, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN090']
#   METAR: 202309211405 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211430 METAR VABB 211430Z 24007KT 3000 -TSRA SCT018 SCT025 FEW030CB BKN080 29/26 Q1008 TEMPO 1500 TSRA=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN080']
#   METAR: 202309211500 METAR VABB 211500Z 24005KT 2200 TSRA FEW010 SCT015 FEW030CB OVC080 28/27 Q1008 TEMPO 1500 TSRA=
#     Wind Dir: 240, Gust: None, Clouds: ['FEW010', 'SCT015', 'FEW030', 'OVC080']
#   METAR: 202309211505 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211530 METAR VABB 211530Z 22004KT 2500 -TSRA FEW012 SCT018 FEW030CB BKN090 28/27 Q1009 TEMPO 1500 TSRA=
#     Wind Dir: 220, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309211600 METAR VABB 211600Z 00000KT 2500 -RA FEW012 SCT018 FEW030CB BKN090 28/27 Q1009 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309211605 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211630 METAR VABB 211630Z 16005KT 2500 -DZ FEW012 SCT018 FEW030CB BKN090 28/27 Q1009 TEMPO 1500 SHRA=
#     Wind Dir: 160, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309211700 METAR VABB 211700Z 14006KT 2500 TS FEW012 SCT018 FEW030CB BKN090 27/27 Q1009 TEMPO 1500 TSRA=
#     Wind Dir: 140, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309211705 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211730 METAR VABB 211730Z 16006KT 2500 TS SCT018 SCT025 FEW030CB BKN090 27/27 Q1009 TEMPO 1500 TSRA=
#     Wind Dir: 160, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN090']
#   METAR: 202309211800 METAR VABB 211800Z 24007KT 1400 R27/2000 TSRA SCT010 SCT015 FEW030CB OVC080 27/27 Q1009 TEMPO 0800 +TSRA=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT010', 'SCT015', 'FEW030', 'OVC080']
#
# Row 29: Validity 211800 to 212200
#   METAR: 202309211800 METAR VABB 211800Z 24007KT 1400 R27/2000 TSRA SCT010 SCT015 FEW030CB OVC080 27/27 Q1009 TEMPO 0800 +TSRA=
#     Wind Dir: 240, Gust: None, Clouds: ['SCT010', 'SCT015', 'FEW030', 'OVC080']
#   METAR: 202309211805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211830 METAR VABB 211830Z 29008KT 1100 R27/1500 +TSRA SCT008 SCT015 FEW030CB OVC080 27/27 Q1009 TEMPO 0800 +TSRA=
#     Wind Dir: 290, Gust: None, Clouds: ['SCT008', 'SCT015', 'FEW030', 'OVC080']
#   METAR: 202309211900 METAR VABB 211900Z 23005KT 1800 TSRA SCT010 SCT018 FEW030CB OVC080 27/27 Q1009 TEMPO 1500 TSRA=
#     Wind Dir: 230, Gust: None, Clouds: ['SCT010', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309211905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309211930 METAR VABB 211930Z 00000KT 2200 -TSRA FEW012 SCT018 FEW030CB OVC080 26/26 Q1008 TEMPO 1500 TSRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309212000 METAR VABB 212000Z 00000KT 2200 -RA FEW012 SCT018 FEW030CB OVC080 27/27 Q1008 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309212005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309212030 METAR VABB 212030Z 13005KT 2200 -RA FEW012 SCT018 FEW030CB OVC080 27/27 Q1008 TEMPO 1500 SHRA=
#     Wind Dir: 130, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309212100 METAR VABB 212100Z 12004KT 2200 -RA FEW012 SCT018 FEW030CB OVC080 27/27 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 120, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309212105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309212130 METAR VABB 212130Z 13006KT 2100 -RA FEW012 SCT018 FEW030CB OVC090 27/27 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 130, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC090']
#   METAR: 202309212200 METAR VABB 212200Z 00000KT 2100 -RA FEW012 SCT018 FEW030CB OVC090 27/26 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC090']
#
# Row 30: Validity 212200 to 220200
#   METAR: 202309212200 METAR VABB 212200Z 00000KT 2100 -RA FEW012 SCT018 FEW030CB OVC090 27/26 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC090']
#   METAR: 202309212205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309212230 METAR VABB 212230Z 00000KT 2200 -RA FEW012 SCT018 FEW030CB OVC090 26/26 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC090']
#   METAR: 202309212300 METAR VABB 212300Z 15004KT 2100 DZ FEW012 SCT018 FEW030CB OVC090 26/25 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 150, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC090']
#   METAR: 202309212305 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309212330 METAR VABB 212330Z 14004KT 2100 DZ FEW012 SCT018 FEW030CB OVC090 26/26 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 140, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC090']
#   METAR: 202309220000 METAR VABB 220000Z 00000KT 2200 -DZ FEW012 SCT018 FEW030CB OVC090 26/26 Q1007 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC090']
#   METAR: 202309220005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309220030 METAR VABB 220030Z 20003KT 2500 HZ SCT018 FEW030CB BKN090 26/26 Q1007 NOSIG=
#     Wind Dir: 200, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309220100 METAR VABB 220100Z 00000KT 2200 HZ SCT018 FEW025TCU BKN090 27/26 Q1007 NOSIG=
#     Wind Dir: 0, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309220105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309220130 METAR VABB 220130Z 00000KT 2200 HZ SCT018 FEW025TCU BKN090 27/27 Q1008 NOSIG=
#     Wind Dir: 0, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309220200 METAR VABB 220200Z 00000KT 2200 HZ SCT018 FEW025TCU BKN090 27/27 Q1008 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#
# Row 31: FCST/OBS is NAN, skipping extraction.
#
# Row 32: Validity 221600 to 222000
#   METAR: 202309221600 METAR VABB 221600Z 00000KT 2100 DZ FEW012 SCT018 FEW030CB BKN090 27/27 Q1009 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309221605 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309221630 METAR VABB 221630Z 14004KT 2100 BR FEW012 SCT018 FEW030CB BKN090 27/27 Q1009 TEMPO 1500 SHRA=
#     Wind Dir: 140, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309221700 METAR VABB 221700Z 13003KT 2100 DZ FEW012 SCT018 FEW030CB BKN090 27/27 Q1009 TEMPO 1500 SHRA=
#     Wind Dir: 130, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309221705 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309221730 METAR VABB 221730Z 00000KT 2100 BR SCT018 FEW030CB BKN090 27/27 Q1009 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309221800 METAR VABB 221800Z 14004KT 2100 BR SCT018 FEW030CB BKN090 27/27 Q1009 NOSIG=
#     Wind Dir: 140, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309221805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
# ...
#     Wind Dir: 70, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309271605 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309271630 METAR VABB 271630Z 09006KT 2200 BR FEW010 SCT018 FEW030CB OVC080 27/26 Q1008 NOSIG=
#     Wind Dir: 90, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309271700 METAR VABB 271700Z 09006KT 2200 BR FEW010 SCT018 FEW030CB OVC080 26/26 Q1008 NOSIG=
#     Wind Dir: 90, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309271705 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309271730 METAR VABB 271730Z 08006KT 2200 BR FEW010 SCT018 FEW030CB OVC080 26/25 Q1008 NOSIG=
#     Wind Dir: 80, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309271800 METAR VABB 271800Z 03006KT 2200 BR FEW010 SCT018 FEW030CB OVC080 27/25 Q1007 NOSIG=
#     Wind Dir: 30, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309271805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309271830 METAR VABB 271830Z 00000KT 2500 BR FEW010 SCT018 FEW030CB OVC080 26/25 Q1007 NOSIG=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'OVC080']
#   METAR: 202309271900 METAR VABB 271900Z 14003KT 2500 BR FEW010 SCT018 FEW030CB OVC080 27/25 Q1007 NOSIG=
#     Wind Dir: 140, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'OVC080']
#
# Row 46: Validity 280730 to 281130
#   METAR: 202309280730 METAR VABB 280730Z 01005KT 2500 HZ SCT020 FEW025TCU SCT100 34/27 Q1005 NOSIG=
#     Wind Dir: 10, Gust: None, Clouds: ['SCT020', 'FEW025', 'SCT100']
#   METAR: 202309280800 METAR VABB 280800Z 30008KT 2500 HZ SCT020 FEW025TCU BKN100 33/28 Q1005 NOSIG=
#     Wind Dir: 300, Gust: None, Clouds: ['SCT020', 'FEW025', 'BKN100']
#   METAR: 202309280805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309280830 METAR VABB 280830Z 27008KT 2500 HZ SCT020 FEW025TCU BKN100 32/27 Q1004 NOSIG=
#     Wind Dir: 270, Gust: None, Clouds: ['SCT020', 'FEW025', 'BKN100']
#   METAR: 202309280900 METAR VABB 280900Z 27010KT 2500 TSRA SCT028 FEW030TCU BKN090 32/28 Q1004 TEMPO 1500 TSRA=
#     Wind Dir: 270, Gust: None, Clouds: ['SCT028', 'FEW030', 'BKN090']
#   METAR: 202309280905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309280930 METAR VABB 280930Z 30011KT 2500 VCSH SCT018 FEW030CB BKN090 31/28 Q1004 TEMPO 1500 SHRA=
#     Wind Dir: 300, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309281000 METAR VABB 281000Z 24012G22KT 0400 R27/0500 +TSRA FEW008 SCT015 FEW030CB BKN090 29/29 Q1004 TEMPO 0150 +TSRA=
#     Wind Dir: 240, Gust: 22, Clouds: ['FEW008', 'SCT015', 'FEW030', 'BKN090']
#   METAR: 202309281005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309281030 METAR VABB 281030Z 34011KT 2100 -TSRA FEW008 SCT015 FEW030CB OVC090 25/24 Q1004 TEMPO 1500 -TSRA=
#     Wind Dir: 340, Gust: None, Clouds: ['FEW008', 'SCT015', 'FEW030', 'OVC090']
#   METAR: 202309281100 METAR VABB 281100Z 27004KT 2500 HZ FEW012 SCT018 FEW030CB BKN090 26/26 Q1003 TEMPO 1500 SHRA=
#     Wind Dir: 270, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309281105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309281130 METAR VABB 281130Z 36004KT 2500 HZ FEW012 SCT018 FEW030CB OVC090 28/26 Q1003 TEMPO 1500 SHRA=
#     Wind Dir: 360, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'OVC090']
#
# Row 47: FCST/OBS is OBS, skipping extraction.
#
# Row 48: FCST/OBS is OBS, skipping extraction.
#
# Row 49: Validity 290730 to 291130
#   METAR: 202309290730 METAR VABB 290730Z 30006KT 2100 BR SCT018 FEW030CB BKN090 31/29 Q1005 NOSIG=
#     Wind Dir: 300, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309290800 METAR VABB 290800Z 26006KT 2100 BR SCT018 FEW030CB BKN090 32/28 Q1004 NOSIG=
#     Wind Dir: 260, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309290805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309290830 METAR VABB 290830Z 25010KT 2100 BR SCT018 FEW030CB BKN090 33/29 Q1003 NOSIG=
#     Wind Dir: 250, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309290900 METAR VABB 290900Z 29011KT 2100 HZ SCT018 FEW030CB BKN090 34/29 Q1003 NOSIG=
#     Wind Dir: 290, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309290905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309290930 METAR VABB 290930Z 31009KT 2200 HZ SCT018 FEW030CB BKN090 32/28 Q1002 NOSIG=
#     Wind Dir: 310, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291000 METAR VABB 291000Z 33007KT 2500 HZ SCT018 FEW030CB BKN090 31/24 Q1002 TEMPO 1500 SHRA=
#     Wind Dir: 330, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291030 METAR VABB 291030Z 35009KT 2500 HZ SCT018 FEW030CB BKN090 31/24 Q1002 TEMPO 1500 SHRA=
#     Wind Dir: 350, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291100 METAR VABB 291100Z 35007KT 2500 HZ SCT018 FEW030CB BKN090 30/26 Q1003 TEMPO 1500 SHRA=
#     Wind Dir: 350, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291130 METAR VABB 291130Z 00000KT 2500 HZ SCT018 FEW030CB BKN090 30/26 Q1002 NOSIG=
#     Wind Dir: 0, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#
# Row 50: Validity 291130 to 291530
#   METAR: 202309291130 METAR VABB 291130Z 00000KT 2500 HZ SCT018 FEW030CB BKN090 30/26 Q1002 NOSIG=
#     Wind Dir: 0, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291200 METAR VABB 291200Z 34004KT 2500 HZ SCT018 FEW030CB BKN090 31/27 Q1002 NOSIG=
#     Wind Dir: 340, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291230 METAR VABB 291230Z 04005KT 2100 HZ SCT018 FEW030CB BKN090 30/27 Q1003 TEMPO 1500 SHRA=
#     Wind Dir: 40, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291300 METAR VABB 291300Z 07007KT 2100 HZ SCT018 FEW030CB BKN090 29/27 Q1004 TEMPO 1500 SHRA=
#     Wind Dir: 70, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291305 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291330 METAR VABB 291330Z 03009G20KT 2200 VCSH SCT018 SCT025 FEW030CB BKN090 27/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 30, Gust: 20, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN090']
#   METAR: 202309291400 METAR VABB 291400Z 06010KT 2500 -TSRA SCT018 SCT025 FEW030CB BKN090 26/24 Q1006 TEMPO 1500 TSRA=
#     Wind Dir: 60, Gust: None, Clouds: ['SCT018', 'SCT025', 'FEW030', 'BKN090']
#   METAR: 202309291405 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291430 METAR VABB 291430Z 06006KT 2200 -TSRA SCT012 SCT015 FEW030CB BKN080 26/24 Q1006 TEMPO 1500 TSRA=
#     Wind Dir: 60, Gust: None, Clouds: ['SCT012', 'SCT015', 'FEW030', 'BKN080']
#   METAR: 202309291500 METAR VABB 291500Z 10005KT 2200 -TSRA SCT012 SCT015 FEW030CB BKN080 26/25 Q1006 TEMPO 1500 TSRA=
#     Wind Dir: 100, Gust: None, Clouds: ['SCT012', 'SCT015', 'FEW030', 'BKN080']
#   METAR: 202309291505 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291530 METAR VABB 291530Z 03006KT 2200 -TSRA SCT012 SCT015 FEW030CB BKN080 26/25 Q1006 TEMPO 1500 TSRA=
#     Wind Dir: 30, Gust: None, Clouds: ['SCT012', 'SCT015', 'FEW030', 'BKN080']
#
# Row 51: Validity 291530 to 291930
#   METAR: 202309291530 METAR VABB 291530Z 03006KT 2200 -TSRA SCT012 SCT015 FEW030CB BKN080 26/25 Q1006 TEMPO 1500 TSRA=
#     Wind Dir: 30, Gust: None, Clouds: ['SCT012', 'SCT015', 'FEW030', 'BKN080']
#   METAR: 202309291600 METAR VABB 291600Z 04004KT 2100 -RA SCT010 SCT015 FEW030CB OVC080 26/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 40, Gust: None, Clouds: ['SCT010', 'SCT015', 'FEW030', 'OVC080']
#   METAR: 202309291605 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291630 METAR VABB 291630Z 05008KT 2100 BR FEW012 SCT018 FEW030CB BKN090 26/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 50, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291700 METAR VABB 291700Z 05009KT 2200 BR SCT018 FEW030CB BKN090 26/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 50, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291705 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291730 METAR VABB 291730Z 08005KT 2500 BR SCT018 FEW030CB BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 80, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291800 METAR VABB 291800Z 11003KT 2500 BR SCT018 FEW025TCU BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 110, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309291805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291830 METAR VABB 291830Z 00000KT 2500 BR SCT018 FEW025TCU BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 0, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309291900 METAR VABB 291900Z 11004KT 2500 BR SCT018 FEW025TCU BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 110, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309291905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291930 METAR VABB 291930Z 12004KT 2500 BR SCT018 FEW025TCU BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 120, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#
# Row 52: Validity 291530 to 291930
#   METAR: 202309291530 METAR VABB 291530Z 03006KT 2200 -TSRA SCT012 SCT015 FEW030CB BKN080 26/25 Q1006 TEMPO 1500 TSRA=
#     Wind Dir: 30, Gust: None, Clouds: ['SCT012', 'SCT015', 'FEW030', 'BKN080']
#   METAR: 202309291600 METAR VABB 291600Z 04004KT 2100 -RA SCT010 SCT015 FEW030CB OVC080 26/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 40, Gust: None, Clouds: ['SCT010', 'SCT015', 'FEW030', 'OVC080']
#   METAR: 202309291605 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291630 METAR VABB 291630Z 05008KT 2100 BR FEW012 SCT018 FEW030CB BKN090 26/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 50, Gust: None, Clouds: ['FEW012', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291700 METAR VABB 291700Z 05009KT 2200 BR SCT018 FEW030CB BKN090 26/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 50, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291705 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291730 METAR VABB 291730Z 08005KT 2500 BR SCT018 FEW030CB BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 80, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309291800 METAR VABB 291800Z 11003KT 2500 BR SCT018 FEW025TCU BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 110, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309291805 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291830 METAR VABB 291830Z 00000KT 2500 BR SCT018 FEW025TCU BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 0, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309291900 METAR VABB 291900Z 11004KT 2500 BR SCT018 FEW025TCU BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 110, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202309291905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309291930 METAR VABB 291930Z 12004KT 2500 BR SCT018 FEW025TCU BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 120, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#
# Row 53: FCST/OBS is OBS, skipping extraction.
#
# Row 54: FCST/OBS is OBS, skipping extraction.
#
# Row 55: Validity 301830 to 302230
#   METAR: 202309301830 METAR VABB 301830Z 25004KT 2100 BR SCT018 FEW030CB BKN090 27/25 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 250, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309301900 METAR VABB 301900Z 17004KT 2100 BR SCT018 FEW030CB BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 170, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309301905 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309301930 METAR VABB 301930Z 16005KT 2100 BR SCT018 FEW030CB BKN090 27/25 Q1005 NOSIG=
#     Wind Dir: 160, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309302000 METAR VABB 302000Z 14007KT 2100 -RA SCT018 FEW030CB BKN090 27/26 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 140, Gust: None, Clouds: ['SCT018', 'FEW030', 'BKN090']
#   METAR: 202309302005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309302030 METAR VABB 302030Z 14008KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 26/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 140, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309302100 METAR VABB 302100Z 17005KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 26/25 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 170, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309302105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309302130 METAR VABB 302130Z 00000KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 26/25 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309302200 METAR VABB 302200Z 00000KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 26/25 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309302205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309302230 METAR VABB 302230Z 29003KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 26/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 290, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#
# Row 56: Validity 302230 to 0102300
#   METAR: 202309302230 METAR VABB 302230Z 29003KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 26/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 290, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309302300 METAR VABB 302300Z 26004KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 26/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 260, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202309302305 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202309302330 METAR VABB 302330Z 00000KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 27/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202310010000 METAR VABB 010000Z 00000KT 2100 -RA FEW010 SCT018 FEW030CB BKN090 26/26 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 0, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202310010005 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202310010030 METAR VABB 010030Z 04004KT 2100 VCSH FEW010 SCT018 FEW030CB BKN090 27/27 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 40, Gust: None, Clouds: ['FEW010', 'SCT018', 'FEW030', 'BKN090']
#   METAR: 202310010100 METAR VABB 010100Z 10004KT 2100 BR SCT018 FEW025TCU BKN090 27/27 Q1005 TEMPO 1500 SHRA=
#     Wind Dir: 100, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202310010105 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202310010130 METAR VABB 010130Z 16003KT 2100 BR SCT018 FEW025TCU BKN090 27/27 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 160, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202310010200 METAR VABB 010200Z 14004KT 2100 BR SCT018 FEW025TCU BKN090 27/27 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 140, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
#   METAR: 202310010205 METAR VABB NIL=
#     Wind Dir: None, Gust: None, Clouds: []
#   METAR: 202310010230 METAR VABB 010230Z 12004KT 1800 BR SCT018 FEW025TCU BKN090 27/27 Q1006 TEMPO 1500 SHRA=
#     Wind Dir: 120, Gust: None, Clouds: ['SCT018', 'FEW025', 'BKN090']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
